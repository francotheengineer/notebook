# %%
# dlib trial

# %%
import sys
import dlib
from skimage import io


from PIL import Image # 画像表示用
import matplotlib.pyplot as plt # 画像表示用

# %%
detector = dlib.get_frontal_face_detector()

# %%
img = io.imread("data/image4.jpg")

# %%
dets = detector(img, 1)

# %%
print("Number of faces detected: {}".format(len(dets)))
# Out:
# Number of faces detected: 1

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.imshow(img)

for i, d in enumerate(dets):
    print("Detection {}: Left: {} Top: {} Right: {} Bottom: {}".format(
        i, d.left(),  d.top(), d.right(), d.bottom()))
    ax.add_patch(plt.Rectangle((d.left(), d.bottom()), d.right() - d.left(), d.top() - d.bottom(), fill=False, edgecolor="yellow"))

plt.show()
# Out:
# Detection 0: Left: 235 Top: 307 Right: 556 Bottom: 628

# %%
from scipy import misc 

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
for i, d in enumerate(dets):
    print("Detection {}: Left: {} Top: {} Right: {} Bottom: {}".format(
        i, d.left(),  d.top(), d.right(), d.bottom()))
    imgt = img[d.top()-50:d.bottom()+50, d.left()-50:d.right()+50, :]
    imgt = misc.imresize(imgt, (230, 230), 'bicubic')
    plt.imshow(imgt)
    
plt.show()

io.imsave("./data/base_face.jpg", imgt)
# Out:
# Detection 0: Left: 235 Top: 307 Right: 556 Bottom: 628
